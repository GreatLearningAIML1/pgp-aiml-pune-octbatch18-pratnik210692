# %% [markdown]
# ## Deep face recognition with Keras

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Set files_zip_path to the location in the drive where you have the new `'Files_required_for_face_recognition.zip'` file. This block will extract all the files to the current working directory. You should be seeing the list of all files inside the zip files as the output of this block after the final `!ls` command is executed.

# %%
# files_zip_path = "/content/drive/My Drive/Files_required_for_face_recognition.zip"

# import zipfile
# #This extracts the files to the current working directory
# archive = zipfile.ZipFile(files_zip_path, 'r')
# archive.extractall()
# !ls

# %% [markdown]
# ### First, lets install the required libraries. Upload the `requirements.txt` file given and run the below commands.

# %%
# Set current working directory so that all relative path references work

# %cd "/content/drive/My Drive/PGP-AIML/Face Recognition"
# Out:
# /content/drive/My Drive/PGP-AIML/Face Recognition

# %%
from model import create_model

#Disable tensorflow backend warnings
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 

import warnings
# Suppress LabelEncoder warning
warnings.filterwarnings('ignore')

from keras import backend as K
from keras.models import Model
from keras.layers import Input, Layer

from data import triplet_generator


import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
import numpy as np

from keras.models import Sequential
from keras.layers import Dense
from keras import callbacks
# Out:
# /root/.local/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# !pip install -r requirements.txt --user
# Out:
# Requirement already satisfied: absl-py==0.1.10 in /root/.local/lib/python2.7/site-packages (from -r requirements.txt (line 1)) (0.1.10)
# Requirement already satisfied: appnope==0.1.0 in /root/.local/lib/python2.7/site-packages (from -r requirements.txt (line 2)) (0.1.0)
# Requirement already satisfied: bleach==1.5.0 in /root/.local/lib/python2.7/site-packages (from -r requirements.txt (line 3)) (1.5.0)
# Requirement already satisfied: cycler==0.10.0 in /usr/local/lib/python2.7/dist-packages (from -r requirements.txt (line 4)) (0.10.0)
# Requirement already satisfied: decorator==4.2.1 in /root/.local/lib/python2.7/site-packages (from -r requirements.txt (line 5)) (4.2.1)
# Requirement already satisfied: entrypoints==0.2.3 in /root/.local/lib/python2.7/site-packages (from -r requirements.txt (line 6)) (0.2.3)
# Requirement already satisfied: h5py==2.7.1 in /root/.local/lib/python2.7/site-packages (from -r requirements.txt (line 7)) (2.7.1)
# Requirement already satisfied: html5lib==0.9999999 in /root/.local/lib/python2.7/site-packages (from -r requirements.txt (line 8)) (0.9999999)
# Requirement already satisfied: jedi==0.11.1 in /root/.local/lib/python2.7/site-packages (from -r requirements.txt (line 9)) (0.11.1)
# Requirement already satisfied: Jinja2==2.10 in /usr/local/lib/python2.7/dist-packages (from -r requirements.txt (line 10)) (2.10)
# Requirement already satisfied: jsonschema==2.6.0 in /usr/local/lib/python2.7/dist-packages (from -r requirements.txt (line 11)) (2.6.0)
# Requirement already satisfied: jupyter==1.0.0 in /usr/local/lib/python2.7/dist-packages (from -r requirements.txt (line 12)) (1.0.0)
# Requirement already satisfied: jupyter-client==5.2.2 in /root/.local/lib/python2.7/site-packages (from -r requirements.txt (line 13)) (5.2.2)
# Requirement already satisfied: jupyter-console==5.2.0 in /usr/local/lib/python2.7/dist-packages (from -r requirements.txt (line 14)) (5.2.0)
# Requirement already satisfied: jupyter-core==4.4.0 in /usr/local/lib/python2.7/dist-packages (from -r requirements.txt (line 15)) (4.4.0)
# Requirement already satisfied: Keras==2.1.3 in /root/.local/lib/python2.7/site-packages (from -r requirements.txt (line 16)) (2.1.3)
# Requirement already satisfied: Markdown==2.6.11 in /root/.local/lib/python2.7/site-packages (from -r requirements.txt (line 17)) (2.6.11)
# Requirement already satisfied: MarkupSafe==1.0 in /root/.local/lib/python2.7/site-packages (from -r requirements.txt (line 18)) (1.0)
# Requirement already satisfied: matplotlib==2.1.2 in /root/.local/lib/python2.7/site-packages (from -r requirements.txt (line 19)) (2.1.2)
# Requirement already satisfied: mistune==0.8.3 in /root/.local/lib/python2.7/site-packages (from -r requirements.txt (line 20)) (0.8.3)
# Requirement already satisfied: nbconvert==5.3.1 in /root/.local/lib/python2.7/site-packages (from -r requirements.txt (line 21)) (5.3.1)
# Requirement already satisfied: nbformat==4.4.0 in /usr/local/lib/python2.7/dist-packages (from -r requirements.txt (line 22)) (4.4.0)
# Requirement already satisfied: notebook==5.4.0 in /root/.local/lib/python2.7/site-packages (from -r requirements.txt (line 23)) (5.4.0)
# Requirement already satisfied: numpy==1.14.0 in /root/.local/lib/python2.7/site-packages (from -r requirements.txt (line 24)) (1.14.0)
# Requirement already satisfied: opencv-python==3.4.0.12 in /root/.local/lib/python2.7/site-packages (from -r requirements.txt (line 25)) (3.4.0.12)
# Requirement already satisfied: pandocfilters==1.4.2 in /usr/local/lib/python2.7/dist-packages (from -r requirements.txt (line 26)) (1.4.2)
# Requirement already satisfied: parso==0.1.1 in /root/.local/lib/python2.7/site-packages (from -r requirements.txt (line 27)) (0.1.1)
# Requirement already satisfied: pexpect==4.3.1 in /root/.local/lib/python2.7/site-packages (from -r requirements.txt (line 28)) (4.3.1)
# Requirement already satisfied: pickleshare==0.7.4 in /root/.local/lib/python2.7/site-packages (from -r requirements.txt (line 29)) (0.7.4)
# Requirement already satisfied: prompt-toolkit==1.0.15 in /usr/local/lib/python2.7/dist-packages (from -r requirements.txt (line 30)) (1.0.15)
# Requirement already satisfied: protobuf==3.5.1 in /root/.local/lib/python2.7/site-packages (from -r requirements.txt (line 31)) (3.5.1)
# Requirement already satisfied: ptyprocess==0.5.2 in /root/.local/lib/python2.7/site-packages (from -r requirements.txt (line 32)) (0.5.2)
# Requirement already satisfied: Pygments==2.2.0 in /root/.local/lib/python2.7/site-packages (from -r requirements.txt (line 33)) (2.2.0)
# Requirement already satisfied: pyparsing==2.2.0 in /root/.local/lib/python2.7/site-packages (from -r requirements.txt (line 34)) (2.2.0)
# Requirement already satisfied: python-dateutil==2.6.1 in /root/.local/lib/python2.7/site-packages (from -r requirements.txt (line 35)) (2.6.1)
# Requirement already satisfied: pytz==2017.3 in /root/.local/lib/python2.7/site-packages (from -r requirements.txt (line 36)) (2017.3)
# Requirement already satisfied: PyYAML==3.12 in /root/.local/lib/python2.7/site-packages (from -r requirements.txt (line 37)) (3.12)
# Requirement already satisfied: pyzmq==16.0.4 in /root/.local/lib/python2.7/site-packages (from -r requirements.txt (line 38)) (16.0.4)
# Requirement already satisfied: qtconsole==4.3.1 in /root/.local/lib/python2.7/site-packages (from -r requirements.txt (line 39)) (4.3.1)
# Requirement already satisfied: scikit-learn==0.19.1 in /root/.local/lib/python2.7/site-packages (from -r requirements.txt (line 40)) (0.19.1)
# Requirement already satisfied: scipy==1.0.0 in /root/.local/lib/python2.7/site-packages (from -r requirements.txt (line 41)) (1.0.0)
# Requirement already satisfied: Send2Trash==1.4.2 in /root/.local/lib/python2.7/site-packages (from -r requirements.txt (line 42)) (1.4.2)
# Requirement already satisfied: simplegeneric==0.8.1 in /usr/local/lib/python2.7/dist-packages (from -r requirements.txt (line 43)) (0.8.1)
# Requirement already satisfied: six==1.11.0 in /usr/local/lib/python2.7/dist-packages (from -r requirements.txt (line 44)) (1.11.0)
# Requirement already satisfied: tensorflow==1.5.0 in /root/.local/lib/python2.7/site-packages (from -r requirements.txt (line 45)) (1.5.0)
# Requirement already satisfied: tensorflow-tensorboard==1.5.1 in /root/.local/lib/python2.7/site-packages (from -r requirements.txt (line 46)) (1.5.1)
# Requirement already satisfied: terminado==0.8.1 in /root/.local/lib/python2.7/site-packages (from -r requirements.txt (line 47)) (0.8.1)
# Requirement already satisfied: testpath==0.3.1 in /root/.local/lib/python2.7/site-packages (from -r requirements.txt (line 48)) (0.3.1)
# Requirement already satisfied: tornado==4.5.3 in /usr/local/lib/python2.7/dist-packages (from -r requirements.txt (line 49)) (4.5.3)
# Requirement already satisfied: traitlets==4.3.2 in /usr/local/lib/python2.7/dist-packages (from -r requirements.txt (line 50)) (4.3.2)
# Requirement already satisfied: wcwidth==0.1.7 in /usr/local/lib/python2.7/dist-packages (from -r requirements.txt (line 51)) (0.1.7)
# Requirement already satisfied: Werkzeug==0.14.1 in /root/.local/lib/python2.7/site-packages (from -r requirements.txt (line 52)) (0.14.1)
# Requirement already satisfied: widgetsnbextension==3.1.3 in /root/.local/lib/python2.7/site-packages (from -r requirements.txt (line 53)) (3.1.3)
# Requirement already satisfied: configparser>=3.5; python_version == "2.7" in /usr/local/lib/python2.7/dist-packages (from entrypoints==0.2.3->-r requirements.txt (line 6)) (3.7.4)
# Requirement already satisfied: functools32; python_version == "2.7" in /usr/local/lib/python2.7/dist-packages (from jsonschema==2.6.0->-r requirements.txt (line 11)) (3.2.3.post2)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python2.7/dist-packages (from jupyter==1.0.0->-r requirements.txt (line 12)) (7.4.2)
# Requirement already satisfied: ipykernel in /usr/local/lib/python2.7/dist-packages (from jupyter==1.0.0->-r requirements.txt (line 12)) (4.6.1)
# Requirement already satisfied: ipython in /usr/local/lib/python2.7/dist-packages (from jupyter-console==5.2.0->-r requirements.txt (line 14)) (5.5.0)
# Requirement already satisfied: backports.functools-lru-cache in /usr/local/lib/python2.7/dist-packages (from matplotlib==2.1.2->-r requirements.txt (line 19)) (1.5)
# Requirement already satisfied: subprocess32 in /usr/local/lib/python2.7/dist-packages (from matplotlib==2.1.2->-r requirements.txt (line 19)) (3.5.3)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python2.7/dist-packages (from nbformat==4.4.0->-r requirements.txt (line 22)) (0.2.0)
# Requirement already satisfied: pathlib2; python_version in "2.6 2.7 3.2 3.3" in /usr/local/lib/python2.7/dist-packages (from pickleshare==0.7.4->-r requirements.txt (line 29)) (2.3.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python2.7/dist-packages (from protobuf==3.5.1->-r requirements.txt (line 31)) (40.9.0)
# Requirement already satisfied: mock>=2.0.0 in /usr/local/lib/python2.7/dist-packages (from tensorflow==1.5.0->-r requirements.txt (line 45)) (2.0.0)
# Requirement already satisfied: wheel in /usr/local/lib/python2.7/dist-packages (from tensorflow==1.5.0->-r requirements.txt (line 45)) (0.33.1)
# Requirement already satisfied: backports.weakref>=1.0rc1 in /usr/local/lib/python2.7/dist-packages (from tensorflow==1.5.0->-r requirements.txt (line 45)) (1.0.post1)
# Requirement already satisfied: enum34>=1.1.6 in /usr/local/lib/python2.7/dist-packages (from tensorflow==1.5.0->-r requirements.txt (line 45)) (1.1.6)
# Requirement already satisfied: futures>=3.1.1; python_version < "3" in /usr/local/lib/python2.7/dist-packages (from tensorflow-tensorboard==1.5.1->-r requirements.txt (line 46)) (3.2.0)
# Requirement already satisfied: singledispatch in /usr/local/lib/python2.7/dist-packages (from tornado==4.5.3->-r requirements.txt (line 49)) (3.4.0.3)
# Requirement already satisfied: certifi in /usr/local/lib/python2.7/dist-packages (from tornado==4.5.3->-r requirements.txt (line 49)) (2019.3.9)
# Requirement already satisfied: backports_abc>=0.4 in /usr/local/lib/python2.7/dist-packages (from tornado==4.5.3->-r requirements.txt (line 49)) (0.5)
# Requirement already satisfied: backports.shutil-get-terminal-size; python_version == "2.7" in /usr/local/lib/python2.7/dist-packages (from ipython->jupyter-console==5.2.0->-r requirements.txt (line 14)) (1.0.0)
# Requirement already satisfied: scandir; python_version < "3.5" in /usr/local/lib/python2.7/dist-packages (from pathlib2; python_version in "2.6 2.7 3.2 3.3"->pickleshare==0.7.4->-r requirements.txt (line 29)) (1.10.0)
# Requirement already satisfied: funcsigs>=1; python_version < "3.3" in /usr/local/lib/python2.7/dist-packages (from mock>=2.0.0->tensorflow==1.5.0->-r requirements.txt (line 45)) (1.0.2)
# Requirement already satisfied: pbr>=0.11 in /usr/local/lib/python2.7/dist-packages (from mock>=2.0.0->tensorflow==1.5.0->-r requirements.txt (line 45)) (5.1.3)

# %%
# !pip install request
# Out:
# Requirement already satisfied: request in /usr/local/lib/python2.7/dist-packages (2019.3.22)
# Requirement already satisfied: post in /usr/local/lib/python2.7/dist-packages (from request) (2019.3.22)
# Requirement already satisfied: get in /usr/local/lib/python2.7/dist-packages (from request) (2019.3.22)
# Requirement already satisfied: setuptools in /usr/local/lib/python2.7/dist-packages (from request) (40.9.0)
# Requirement already satisfied: query-string in /usr/local/lib/python2.7/dist-packages (from get->request) (2019.3.22)
# Requirement already satisfied: public in /usr/local/lib/python2.7/dist-packages (from query-string->get->request) (2019.3.22)

# %% [markdown]
# ### Training the network
#
# The CNN model is taken from the Keras-OpenFace project. The architecture details aren't too important here, it's only useful to know that there is a fully connected layer with 128 hidden units followed by an L2 normalization layer on top of the convolutional base. These two top layers are referred to as the embedding layer from which the 128-dimensional embedding vectors can be obtained. The complete model is defined in `model.py` and a graphical overview is given in `model.png`. A Keras version of the `nn4.small2` model can be created with `create_model()`.
#
#
# **Run the below code to initialize the model**

# %%
# nn4_small2 = create_model()

# %% [markdown]
# #### Idea of Training the model with Triplet loss function

# %% [markdown]
# Model training aims to learn an embedding f(x) of image x such that the squared L2 distance between all faces of the same identity is small and the distance between a pair of faces from different identities is large. This can be achieved with a triplet loss L that is minimized when the distance between an anchor image xai and a positive image xpi (same identity) in embedding space is smaller than the distance between that anchor image and a negative image xni (different identity) by at least a margin α.

# %%
# # Input for anchor, positive and negative images
# in_a = Input(shape=(96, 96, 3))
# in_p = Input(shape=(96, 96, 3))
# in_n = Input(shape=(96, 96, 3))

# # Output for anchor, positive and negative embedding vectors
# # The nn4_small model instance is shared (Siamese network)
# emb_a = nn4_small2(in_a)
# emb_p = nn4_small2(in_p)
# emb_n = nn4_small2(in_n)

# class TripletLossLayer(Layer):
#     def __init__(self, alpha, **kwargs):
#         self.alpha = alpha
#         super(TripletLossLayer, self).__init__(**kwargs)
    
#     def triplet_loss(self, inputs):
#         a, p, n = inputs
#         p_dist = K.sum(K.square(a-p), axis=-1)
#         n_dist = K.sum(K.square(a-n), axis=-1)
#         return K.sum(K.maximum(p_dist - n_dist + self.alpha, 0), axis=0)
    
#     def call(self, inputs):
#         loss = self.triplet_loss(inputs)
#         self.add_loss(loss)
#         return loss

# # Layer that computes the triplet loss from anchor, positive and negative embedding vectors
# triplet_loss_layer = TripletLossLayer(alpha=0.2, name='triplet_loss_layer')([emb_a, emb_p, emb_n])

# # Model that can be trained with anchor, positive negative images
# nn4_small2_train = Model([in_a, in_p, in_n], triplet_loss_layer)

# %%
# # triplet_generator() creates a generator that continuously returns 
# # ([a_batch, p_batch, n_batch], None) tuples where a_batch, p_batch 
# # and n_batch are batches of anchor, positive and negative RGB images 
# # each having a shape of (batch_size, 96, 96, 3).
# generator = triplet_generator() 

# nn4_small2_train.compile(loss=None, optimizer='adam')
# nn4_small2_train.fit_generator(generator, epochs=10, steps_per_epoch=100)

# # Please note that the current implementation of the generator only generates 
# # random image data. The main goal of this code snippet is to demonstrate 
# # the general setup for model training. In the following, we will anyway 
# # use a pre-trained model so we don't need a generator here that operates 
# # on real training data.

# %% [markdown]
# For this project, we are considering a pre-trained model given in file path **`nn4.small2.v1.h5`**.
#
# # 1. Using **load_weights()** function load the given pre-trained weight file. **- 10 Marks**

# %%
nn4_small2_pretrained = create_model()

nn4_small2_pretrained.load_weights('nn4.small2.v1.h5', by_name=True)
# Out:
# WARNING:tensorflow:From /root/.local/lib/python2.7/site-packages/keras/backend/tensorflow_backend.py:3148: calling l2_normalize (from tensorflow.python.ops.nn_impl) with dim is deprecated and will be removed in a future version.
# Instructions for updating:
# dim is deprecated, use axis instead

# %% [markdown]
# ### Dataset

# %% [markdown]
# To demonstrate face recognition on a custom dataset, a small dataset is used. It consists of around 15-25 face images of 10 different persons. The metadata for each image (file and identity name) are loaded into memory for later processing.
#
#
# Upload Images zip file given to drive and download and extract it using the below code. And we will pass the folder `images` to `load_metadata` function to save all the images filenames and person numbers.

# %% [markdown]
# #### Import drive module from google.colab

# %%
# from google.colab import drive

# %% [markdown]
# #### Give a path to mount the files in your drive

# %%
# drive.mount('/content/drive')

# %% [markdown]
# #### Using the above given mounted path, give the images.zip path dependent on where you placed the file in your drive.

# %%
images_path = "/content/drive/My Drive/PGP-AIML/Face Recognition/images"

# %% [markdown]
# #### Using ZipFile module to extract the images zip file

# %%
# from zipfile import ZipFile

# %%
# with ZipFile(images_path, 'r') as zip:
#   zip.extractall()

# %% [markdown]
# #### Run the below function to load the images from the extracted images folder from the above step and map each image with person id

# %%
import numpy as np
from os import listdir, makedirs
from os.path import isfile, isdir, join, exists
import shutil

class IdentityMetadata():
    def __init__(self, base, name, file):
        # print(base, name, file)
        # dataset base directory
        self.base = base
        # identity name
        self.name = name
        # image file name
        self.file = file

    def __repr__(self):
        return self.image_path()

    def image_path(self):
        return os.path.join(self.base, self.name, self.file) 
      
      
def load_metadata(path):
    metadata = []

    dirs = [d for d in listdir(images_path) if (isdir(join(images_path, d)))]

    for dir_ in dirs:
      jpgs = [f for f in listdir(join(images_path, dir_)) \
              if (isfile(join(images_path, dir_, f)) \
                  and \
                  ((f.endswith('.jpg')) \
                   or\
                   (f.endswith('.jpeg'))))]
      print("Directory '{:>2}' has {} images".format(dir_, len(jpgs)))
  
      for jpg in jpgs:
        metadata.append(IdentityMetadata(path, dir_, jpg))

    return np.array(metadata)

metadata = load_metadata(images_path)
# Out:
# Directory ' 1' has 22 images
# Directory ' 5' has 22 images
# Directory ' 3' has 5 images
# Directory ' 6' has 20 images
# Directory ' 7' has 20 images
# Directory '10' has 19 images
# Directory ' 8' has 29 images
# Directory ' 0' has 21 images
# Directory ' 2' has 20 images
# Directory ' 4' has 3 images
# Directory ' 9' has 20 images

# %%
print(metadata[0].base) # The root folder for all images
print(metadata[0].name) # Name of the containing folder (assumed to be the 'name' of the face recignition subject)
print(metadata[0].file) # Name of the current image that has the face of the face recignition subject
print(metadata[0])      # Full path of the image
# Out:
# /content/drive/My Drive/PGP-AIML/Face Recognition/images
# 1
# image_0446.jpg
# /content/drive/My Drive/PGP-AIML/Face Recognition/images/1/image_0446.jpg

# %%
print(len(metadata))
# Out:
# 201

# %% [markdown]
# ### Face Crop
# The nn4.small2.v1 model was trained with cropped face images, therefore, the face images from the custom dataset must be cropped too. Here, we use the face detection model we built in Milestone 2 and use it to detect faces and crop the faces to pass to our model.

# %% [markdown]
# ##### 1. Import the pre-trained model from milestone 2. You would need all the python files required for the face-detection assignment and the trained weights as well

# %%
from mn_model import mn_model
from face_generator import BatchGenerator
from keras_ssd_loss import SSDLoss
from ssd_box_encode_decode_utils import SSDBoxEncoder, decode_y, decode_y2
from keras.models import load_model
from keras import backend as K

img_height =512
img_width = 512

img_channels = 3

n_classes =2 
class_names = ["background","face"]

scales = [0.07, 0.15, 0.33, 0.51, 0.69, 0.87, 1.05] # anchorboxes for coco dataset
aspect_ratios = [[0.5, 1.0, 2.0],
                 [1.0/3.0, 0.5, 1.0, 2.0, 3.0],
                 [1.0/3.0, 0.5, 1.0, 2.0, 3.0],
                 [1.0/3.0, 0.5, 1.0, 2.0, 3.0],
                 [0.5, 1.0, 2.0],
                 [0.5, 1.0, 2.0]] # The anchor box aspect ratios used in the original SSD300
two_boxes_for_ar1 = True
limit_boxes = True # Whether or not you want to limit the anchor boxes to lie entirely within the image boundaries
variances = [0.1, 0.1, 0.2, 0.2] # The variances by which the encoded target coordinates are scaled as in the original implementation
coords = 'centroids' # Whether the box coordinates to be used as targets for the model should be in the 'centroids' or 'minmax' format, see documentation
normalize_coords = True

model, model_layer, img_input, predictor_sizes = mn_model(image_size=(img_height, img_width, img_channels), 
                                                                      n_classes = n_classes,
                                                                      min_scale = None, 
                                                                      max_scale = None, 
                                                                      scales = scales, 
                                                                      aspect_ratios_global = None, 
                                                                      aspect_ratios_per_layer = aspect_ratios, 
                                                                      two_boxes_for_ar1= two_boxes_for_ar1, 
                                                                      limit_boxes=limit_boxes, 
                                                                      variances= variances, 
                                                                      coords=coords, 
                                                                      normalize_coords=normalize_coords)

#model.summary()
model_path = './'
model_name = 'ssd_mobilenet_face_epoch_25_loss0.0916.h5'

model.load_weights(model_path + model_name,  by_name= True)
# Out:
# ====> Model Specific data
# ====> Height, Width, Channels : 512 512 3

# %% [markdown]
# ##### 2. Function to load an image and reverse the channels for matplot lib to show them

# %%
import cv2
def load_image(path):
    img = cv2.imread(path)

    return img

# %% [markdown]
# You can access each image path from `metadata[i].image_path()` where, i is the image number. We can take values from 1 to no.of images in the dataset given and plot them using matplotlib's imshow.

# %%
# Load an image
# for example, loading the image with index 1
one_image = load_image(metadata[1].image_path())

print(one_image.shape)

# %matplotlib inline
import matplotlib.pyplot as plt

plt.figure()

# Show original image
# OpenCV loads images with color channels
# in BGR order. So we need to reverse them everytime we use matplotlib to show the image.
# Otherwise you see the image in false colour
plt.imshow(one_image[...,::-1])
# Out:
# (592, 896, 3)

# %% [markdown]
# ##### 3. A function to get the face bounding box x_min, x_max, y_min and y_max of input image using the face detection model given an image read using cv2.imread.

# %%
def face_bb(test_img, show_img=False):
    img_height =512
    img_width = 512
    img_channels = 3
    _CONF = 0.60
    _IOU = 0.15
    coords = 'centroids' # Whether the box coordinates to be used as targets for the model should be in the 'centroids' or 'minmax' format, see documentation
    normalize_coords = True
    org_height = test_img.shape[0]
    org_width = test_img.shape[1]
    
    resized_img = cv2.resize(test_img, (512, 512))
    test_img_input = np.expand_dims(resized_img,axis=0)
    y_pred = model.predict(test_img_input)
    y_pred_decoded = decode_y2(y_pred,
                                 confidence_thresh=_CONF,
                                iou_threshold=_IOU,
                                top_k='all',
                                input_coords=coords,
                                normalize_coords=normalize_coords,
                                img_height=img_height,
                                img_width=img_width)
    result = y_pred_decoded[0][0]
    det_label = result[0]
    det_conf = result[1]
    det_xmin = result[2]
    det_xmax = result[3]
    det_ymin = result[4]
    det_ymax = result[5]
    
    #Converting to integers as the indexes to images are only integers
    bb = [int(det_xmin),int(det_xmax),int(det_ymin),int(det_ymax)]
    
    if(show_img == True):      
      # Create figure and axes
      fig,ax = plt.subplots(1)

      # Display the image
      ax.imshow(resized_img[...,::-1], extent=[0, img_width, 0, img_height])
      
      lower_left = (det_xmin, det_ymin)
      width = det_xmax - det_xmin
      height = det_ymax - det_ymin
      
      print('-' * 40)
      print("RESIZED IMAGE WITH BOUNDING BOX FOR FACE\n" + '-' * 40)
      print(" lower left={}\n width={}\n height={}".format(lower_left, width, height))
      print(" xmin={}, ymin={}, xmax={}, ymax={}".format(bb[0], bb[2], bb[1], bb[3]))

      # Create a Rectangle patch
      rect = patches.Rectangle(lower_left, 
                               width, 
                               height, 
                               linewidth=1, 
                               edgecolor='r', 
                               facecolor='none')

      # Add the patch to the Axes
      ax.add_patch(rect)

      plt.show()
    
    return resized_img, bb

# %%
face_bb(load_image(metadata[1].image_path()), show_img=True); # Suppress automatically printing the output
# Out:
# ----------------------------------------
# RESIZED IMAGE WITH BOUNDING BOX FOR FACE
# ----------------------------------------
#  lower left=(171.48345947265625, 102.35212707519531)
#  width=152.776885986
#  height=292.647323608
#  xmin=171, ymin=102, xmax=324, ymax=394

# %% [markdown]
# # 2. Write a function to get the resized cropped out face of an input image from the path given using the face_bb() function defined above. - 10 Marks
# Hint: The face_bb() function gives a list of bounding box co-ordinate values like **[x_min,x_max,y_min,y_max]**. Use **cv2.imread()** to load an image from the image path and pass it to the face_bb function as input. You can crop an image by simply accessing the specific values of the image matrix using the co-ordinates as the boundary indexes. But, before cropping we have to resize the input image to (512,512) like done in the **face_bb()** function as the bounding box co-ordinates are for the resized image. A simple crop can be implemented on the resized image by doing **"image[y_min:y_max,x_min:x_max,:]"** .
# You have to then resize the cropped image to a fixed size of (96,96). You can do that using the **cv2.resize()** function again. It takes the second argument as (96,96) this time.

# %%
def get_face(img_path, show_img=False):
  crop_img_width = 96
  crop_img_height = 96
  
  resized_img, bb = face_bb(load_image(img_path), show_img=show_img)

  crop_img = resized_img[bb[2]:bb[3], bb[0]:bb[1]]
  crop_img = cv2.resize(crop_img, (crop_img_width, crop_img_height))

  if(show_img == True):      
    # Create figure and axes
    fig,ax = plt.subplots(1)

    print('-' * 13)
    print("CROPPED IMAGE\n" + '-' * 13)
    print(" width={}\n height={}".format(crop_img_width, crop_img_height))
    
    # Display the image
    ax.imshow(crop_img[...,::-1], extent=[0, crop_img_width, 0, crop_img_height])

    plt.show()

  return crop_img

# %% [markdown]
# # 3. Write code to load 2nd and 3rd images in the metadata using load_image() and show each image and its cropped version side by side for comparison using matplotlib imshow - 20 Marks

# %%
img_path_2nd = metadata[2].image_path()

test_2nd = load_image(img_path_2nd)

fig,ax = plt.subplots(1)

print('-' * 14)
print("ORIGINAL IMAGE\n" + '-' * 14)
ax.imshow(test_2nd[...,::-1])

plt.show()


get_face(img_path_2nd, show_img=True);
# Out:
# --------------
# ORIGINAL IMAGE
# --------------
# ----------------------------------------
# RESIZED IMAGE WITH BOUNDING BOX FOR FACE
# ----------------------------------------
#  lower left=(235.2724151611328, 119.73304748535156)
#  width=144.219833374
#  height=292.647323608
#  xmin=235, ymin=119, xmax=379, ymax=412
# -------------
# CROPPED IMAGE
# -------------
#  width=96
#  height=96

# %%
img_path_3rd = metadata[3].image_path()

test_3rd = load_image(img_path_3rd)

fig,ax = plt.subplots(1)

print('-' * 14)
print("ORIGINAL IMAGE\n" + '-' * 14)
ax.imshow(test_3rd[...,::-1])

plt.show()


get_face(img_path_3rd, show_img=True);
# Out:
# --------------
# ORIGINAL IMAGE
# --------------
# ----------------------------------------
# RESIZED IMAGE WITH BOUNDING BOX FOR FACE
# ----------------------------------------
#  lower left=(241.16390991210938, 171.9390106201172)
#  width=135.519287109
#  height=292.647293091
#  xmin=241, ymin=171, xmax=376, ymax=464
# -------------
# CROPPED IMAGE
# -------------
#  width=96
#  height=96

# %% [markdown]
# ### Generate embeddings for each image in the dataset
#
# Given below is an example to load the first image in the metadata and get its embedding vector from the pre-trained model.

# %% [markdown]
# #### Get embedding vector for first image in the metadata using the pre-trained model

# %%
# Align the image
cropped_img = get_face(metadata[0].image_path())

# Normalising pixel values from [0-255] to [0-1]: scale RGB values to interval [0,1]
img = (cropped_img / 255.).astype(np.float32)

# obtain embedding vector for an image
embedding_vector = nn4_small2_pretrained.predict(np.expand_dims(img, axis=0))

print("PREDICTED EMBEDDING ARRAY SHAPE:")
print(embedding_vector.shape)

print("")
print("INNER EMBEDDING VECTOR SHAPE:")
print(embedding_vector[0].shape)
# Out:
# PREDICTED EMBEDDING ARRAY SHAPE:
# (1, 128)
#
# INNER EMBEDDING VECTOR SHAPE:
# (128,)

# %% [markdown]
# # 4. Write code to iterate through metadata and create embeddings for each image using nn4_small2_pretrained.predict() and store in a list with name `embeddings` - 10 marks
#
# If there is any error in reading any image in the dataset, fill the emebdding vector of that image with 128-zeroes as the final embedding from the model is of length 128.
# Hint: Don't forget to use numpy's expand_dims funtion to convert each image into the shape (1,96,96,3) and take the 0th element of the prediction from the model as the embedding of the image.

# %%
def get_embedding_vector(metadata_item):
  cropped_img = get_face(metadata_item.image_path())

  print "{}...".format(metadata_item.file),   
  
  # Normalising pixel values from [0-255] to [0-1]: scale RGB values to interval [0,1]
  img = (cropped_img / 255.).astype(np.float32)

  # obtain embedding vector for an image
  embedding_vector = nn4_small2_pretrained.predict(np.expand_dims(img, axis=0))

  print("shape={}...DONE!".format(embedding_vector[0].shape))  
  
  return embedding_vector[0]

# %%
embeddings = []

for md in metadata:
  embeddings.append(get_embedding_vector(md))
  
print(len(embeddings))
# Out:
# image_0446.jpg... shape=(128,)...DONE!
# image_0433.jpg... shape=(128,)...DONE!
# image_0444.jpg... shape=(128,)...DONE!
# image_0430.jpg... shape=(128,)...DONE!
# image_0450.jpg... shape=(128,)...DONE!
# image_0435.jpg... shape=(128,)...DONE!
# image_0447.jpg... shape=(128,)...DONE!
# image_0432.jpg... shape=(128,)...DONE!
# image_0429.jpg... shape=(128,)...DONE!
# image_0445.jpg... shape=(128,)...DONE!
# image_0431.jpg... shape=(128,)...DONE!
# image_0443.jpg... shape=(128,)...DONE!
# image_0434.jpg... shape=(128,)...DONE!
# image_0438.jpg... shape=(128,)...DONE!
# image_0442.jpg... shape=(128,)...DONE!
# image_0437.jpg... shape=(128,)...DONE!
# image_0449.jpg... shape=(128,)...DONE!
# image_0448.jpg... shape=(128,)...DONE!
# image_0439.jpg... shape=(128,)...DONE!
# image_0436.jpg... shape=(128,)...DONE!
# image_0441.jpg... shape=(128,)...DONE!
# image_0440.jpg... shape=(128,)...DONE!
# image_0386.jpg... shape=(128,)...DONE!
# image_0393.jpg... shape=(128,)...DONE!
# image_0391.jpg... shape=(128,)...DONE!
# image_0378.jpg... shape=(128,)...DONE!
# image_0377.jpg... shape=(128,)...DONE!
# image_0382.jpg... shape=(128,)...DONE!
# image_0385.jpg... shape=(128,)...DONE!
# image_0380.jpg... shape=(128,)...DONE!
# image_0379.jpg... shape=(128,)...DONE!
# image_0398.jpg... shape=(128,)...DONE!
# image_0390.jpg... shape=(128,)...DONE!
# image_0397.jpg... shape=(128,)...DONE!
# image_0389.jpg... shape=(128,)...DONE!
# image_0387.jpg... shape=(128,)...DONE!
# image_0388.jpg... shape=(128,)...DONE!
# image_0381.jpg... shape=(128,)...DONE!
# image_0384.jpg... shape=(128,)...DONE!
# image_0383.jpg... shape=(128,)...DONE!
# image_0395.jpg... shape=(128,)...DONE!
# image_0394.jpg... shape=(128,)...DONE!
# image_0392.jpg... shape=(128,)...DONE!
# image_0396.jpg... shape=(128,)...DONE!
# image_0404.jpg... shape=(128,)...DONE!
# image_0406.jpg... shape=(128,)...DONE!
# image_0407.jpg... shape=(128,)...DONE!
# image_0408.jpg... shape=(128,)...DONE!
# image_0405.jpg... shape=(128,)...DONE!
# image_0375.jpg... shape=(128,)...DONE!
# image_0374.jpg... shape=(128,)...DONE!
# image_0361.jpg... shape=(128,)...DONE!
# image_0360.jpg... shape=(128,)...DONE!
# image_0364.jpg... shape=(128,)...DONE!
# image_0376.jpg... shape=(128,)...DONE!
# image_0359.jpg... shape=(128,)...DONE!
# image_0368.jpg... shape=(128,)...DONE!
# image_0372.jpg... shape=(128,)...DONE!
# image_0358.jpg... shape=(128,)...DONE!
# image_0367.jpg... shape=(128,)...DONE!
# image_0370.jpg... shape=(128,)...DONE!
# image_0369.jpg... shape=(128,)...DONE!
# image_0363.jpg... shape=(128,)...DONE!
# image_0362.jpg... shape=(128,)...DONE!
# image_0371.jpg... shape=(128,)...DONE!
# image_0365.jpg... shape=(128,)...DONE!
# image_0366.jpg... shape=(128,)...DONE!
# image_0357.jpg... shape=(128,)...DONE!
# image_0373.jpg... shape=(128,)...DONE!
# image_0339.jpg... shape=(128,)...DONE!
# image_0343.jpg... shape=(128,)...DONE!
# image_0356.jpg... shape=(128,)...DONE!
# image_0352.jpg... shape=(128,)...DONE!
# image_0340.jpg... shape=(128,)...DONE!
# image_0355.jpg... shape=(128,)...DONE!
# image_0349.jpg... shape=(128,)...DONE!
# image_0341.jpg... shape=(128,)...DONE!
# image_0344.jpg... shape=(128,)...DONE!
# image_0351.jpg... shape=(128,)...DONE!
# image_0353.jpg... shape=(128,)...DONE!
# image_0337.jpg... shape=(128,)...DONE!
# image_0338.jpg... shape=(128,)...DONE!
# image_0354.jpg... shape=(128,)...DONE!
# image_0345.jpg... shape=(128,)...DONE!
# image_0350.jpg... shape=(128,)...DONE!
# image_0346.jpg... shape=(128,)...DONE!
# image_0347.jpg... shape=(128,)...DONE!
# image_0342.jpg... shape=(128,)...DONE!
# image_0348.jpg... shape=(128,)...DONE!
# image_0271.jpg... shape=(128,)...DONE!
# image_0286.jpg... shape=(128,)...DONE!
# image_0287.jpg... shape=(128,)...DONE!
# image_0282.jpg... shape=(128,)...DONE!
# image_0270.jpg... shape=(128,)...DONE!
# image_0274.jpg... shape=(128,)...DONE!
# image_0277.jpg... shape=(128,)...DONE!
# image_0285.jpg... shape=(128,)...DONE!
# image_0281.jpg... shape=(128,)...DONE!
# image_0280.jpg... shape=(128,)...DONE!
# image_0279.jpg... shape=(128,)...DONE!
# image_0273.jpg... shape=(128,)...DONE!
# image_0272.jpg... shape=(128,)...DONE!
# image_0283.jpg... shape=(128,)...DONE!
# image_0275.jpg... shape=(128,)...DONE!
# image_0284.jpg... shape=(128,)...DONE!
# image_0276.jpg... shape=(128,)...DONE!
# image_0269.jpg... shape=(128,)...DONE!
# image_0278.jpg... shape=(128,)...DONE!
# image_0331.jpg... shape=(128,)...DONE!
# image_0316.jpg... shape=(128,)...DONE!
# image_0332.jpg... shape=(128,)...DONE!
# image_0330.jpg... shape=(128,)...DONE!
# image_0311.jpg... shape=(128,)...DONE!
# image_0308.jpg... shape=(128,)...DONE!
# image_0325.jpg... shape=(128,)...DONE!
# image_0320.jpg... shape=(128,)...DONE!
# image_0336.jpg... shape=(128,)...DONE!
# image_0326.jpg... shape=(128,)...DONE!
# image_0327.jpg... shape=(128,)...DONE!
# image_0313.jpg... shape=(128,)...DONE!
# image_0312.jpg... shape=(128,)...DONE!
# image_0317.jpg... shape=(128,)...DONE!
# image_0309.jpg... shape=(128,)...DONE!
# image_0334.jpg... shape=(128,)...DONE!
# image_0335.jpg... shape=(128,)...DONE!
# image_0322.jpg... shape=(128,)...DONE!
# image_0323.jpg... shape=(128,)...DONE!
# image_0333.jpg... shape=(128,)...DONE!
# image_0329.jpg... shape=(128,)...DONE!
# image_0321.jpg... shape=(128,)...DONE!
# image_0310.jpg... shape=(128,)...DONE!
# image_0314.jpg... shape=(128,)...DONE!
# image_0328.jpg... shape=(128,)...DONE!
# image_0318.jpg... shape=(128,)...DONE!
# image_0315.jpg... shape=(128,)...DONE!
# image_0319.jpg... shape=(128,)...DONE!
# image_0324.jpg... shape=(128,)...DONE!
# image_0002.jpg... shape=(128,)...DONE!
# image_0014.jpg... shape=(128,)...DONE!
# image_0006.jpg... shape=(128,)...DONE!
# image_0015.jpg... shape=(128,)...DONE!
# image_0011.jpg... shape=(128,)...DONE!
# image_0012.jpg... shape=(128,)...DONE!
# image_0008.jpg... shape=(128,)...DONE!
# image_0003.jpg... shape=(128,)...DONE!
# image_0016.jpg... shape=(128,)...DONE!
# image_0010.jpg... shape=(128,)...DONE!
# image_0019.jpg... shape=(128,)...DONE!
# image_0017.jpg... shape=(128,)...DONE!
# image_0021.jpg... shape=(128,)...DONE!
# image_0007.jpg... shape=(128,)...DONE!
# image_0005.jpg... shape=(128,)...DONE!
# image_0018.jpg... shape=(128,)...DONE!
# image_0020.jpg... shape=(128,)...DONE!
# image_0009.jpg... shape=(128,)...DONE!
# image_0004.jpg... shape=(128,)...DONE!
# image_0001.jpg... shape=(128,)...DONE!
# image_0013.jpg... shape=(128,)...DONE!
# image_0422.jpg... shape=(128,)...DONE!
# image_0420.jpg... shape=(128,)...DONE!
# image_0415.jpg... shape=(128,)...DONE!
# image_0418.jpg... shape=(128,)...DONE!
# image_0413.jpg... shape=(128,)...DONE!
# image_0423.jpg... shape=(128,)...DONE!
# image_0416.jpg... shape=(128,)...DONE!
# image_0425.jpg... shape=(128,)...DONE!
# image_0409.jpg... shape=(128,)...DONE!
# image_0417.jpg... shape=(128,)...DONE!
# image_0412.jpg... shape=(128,)...DONE!
# image_0428.jpg... shape=(128,)...DONE!
# image_0419.jpg... shape=(128,)...DONE!
# image_0426.jpg... shape=(128,)...DONE!
# image_0427.jpg... shape=(128,)...DONE!
# image_0421.jpg... shape=(128,)...DONE!
# image_0410.jpg... shape=(128,)...DONE!
# image_0424.jpg... shape=(128,)...DONE!
# image_0414.jpg... shape=(128,)...DONE!
# image_0411.jpg... shape=(128,)...DONE!
# image_0402.jpg... shape=(128,)...DONE!
# image_0403.jpg... shape=(128,)...DONE!
# image_0400.jpg... shape=(128,)...DONE!
# image_0294.jpg... shape=(128,)...DONE!
# image_0297.jpg... shape=(128,)...DONE!
# image_0293.jpg... shape=(128,)...DONE!
# image_0288.jpg... shape=(128,)...DONE!
# image_0302.jpg... shape=(128,)...DONE!
# image_0292.jpg... shape=(128,)...DONE!
# image_0303.jpg... shape=(128,)...DONE!
# image_0307.jpg... shape=(128,)...DONE!
# image_0296.jpg... shape=(128,)...DONE!
# image_0295.jpg... shape=(128,)...DONE!
# image_0289.jpg... shape=(128,)...DONE!
# image_0299.jpg... shape=(128,)...DONE!
# image_0298.jpg... shape=(128,)...DONE!
# image_0301.jpg... shape=(128,)...DONE!
# image_0305.jpg... shape=(128,)...DONE!
# image_0291.jpg... shape=(128,)...DONE!
# image_0290.jpg... shape=(128,)...DONE!
# image_0300.jpg... shape=(128,)...DONE!
# image_0304.jpg... shape=(128,)...DONE!
# image_0306.jpg... shape=(128,)...DONE!
# 201

# %%
embeddings[0].shape
# Out:
# (128,)

# %%
embeddings[0]
# Out:
# array([ 0.0936962 ,  0.13785863, -0.08935581, -0.06203979,  0.00551501,
#         0.2141135 ,  0.05559967,  0.00816214, -0.13023432,  0.01259289,
#         0.0947157 , -0.00101905,  0.08642978, -0.09066663,  0.06717391,
#        -0.04879412, -0.04714048, -0.07354809,  0.02540084,  0.05125044,
#         0.06026188, -0.02565294,  0.00406006,  0.10781737,  0.0286012 ,
#        -0.04197363,  0.01258817, -0.17273404,  0.06969656,  0.11658133,
#         0.02803343, -0.08869936, -0.05883734,  0.04169565,  0.00036854,
#         0.02519757, -0.04962147,  0.03604887,  0.02672908,  0.04812507,
#        -0.01563392, -0.12625371, -0.09941831,  0.0640799 , -0.06178197,
#         0.11148793,  0.1224907 , -0.00234741, -0.25716093, -0.00075521,
#        -0.01890853,  0.04215056, -0.00720983, -0.04740318,  0.0084919 ,
#         0.06050779, -0.10445668,  0.20566311, -0.0887694 , -0.00791756,
#        -0.1025537 ,  0.00800694,  0.23410507, -0.1995296 ,  0.09759326,
#        -0.02197795,  0.02654652,  0.04256113, -0.13647342, -0.00663163,
#         0.0035243 ,  0.06347774, -0.16010517, -0.06317533,  0.08451049,
#         0.03169755,  0.00145637,  0.02917554,  0.04916945,  0.1787848 ,
#        -0.101993  , -0.09301693, -0.03408534, -0.04448869, -0.10993759,
#         0.02968697,  0.03511837, -0.1192458 , -0.00876772,  0.05023079,
#         0.06141503, -0.15046783, -0.04684199,  0.10103859, -0.04523779,
#        -0.05519101,  0.04554861, -0.03127419,  0.06478912, -0.03098536,
#        -0.01042361,  0.0587947 , -0.11020622,  0.05822179, -0.18650465,
#         0.13050902, -0.04988306,  0.10275112, -0.04531926, -0.08950434,
#         0.09762186,  0.0655422 , -0.05490923, -0.06017944,  0.06933713,
#         0.11744516, -0.1758713 , -0.0201177 ,  0.04902266,  0.17959121,
#         0.00077959, -0.12861934, -0.03314364,  0.10131139,  0.03076356,
#         0.11935045,  0.02177385, -0.07228944], dtype=float32)

# %%
type(embeddings[0])
# Out:
# numpy.ndarray

# %% [markdown]
# #### Write code to get the distance between the respective embeddings given 2 pairs of images.
#
# Consider distance metric as "Squared L2 distance"
#
# squared l2 distance between 2 points (x1, y1) and (x2, y2) = (x1-x2)^2 + (y1-y2)^2
#
#
#
# # 5. Plot images and get distance between the pairs given below. - 10 Marks
#
# 1. 10,12 and 10,131
#
# 2. 30,31 and 30,100
#
# 3. 70,72 and 70,115

# %%
def get_dist_between_images(ref_img_idx, target_img_idx, show_img=False):
  l = ref_img_idx
  r = target_img_idx
  
  dist = np.square(embeddings[l] - embeddings[r]).sum()
  
  if(show_img == True):
    print("DISTANCE BETWEEN THESE 2 IMAGES = {}".format(dist))

    fig,ax = plt.subplots(1, 2)
    
    ax[0].imshow(load_image(metadata[l].image_path())[...,::-1])
    ax[1].imshow(load_image(metadata[r].image_path())[...,::-1])

    plt.show()
  
  return dist

# %%
def show_dist_between_pairs(ref_img_idx, target_img1_idx, target_img2_idx):
  ref = ref_img_idx
  one = target_img1_idx
  two = target_img2_idx
  
  print('-' * 45)
  pair1_dist = get_dist_between_images(ref, one, True)
  print('.' * 45)
  pair2_dist = get_dist_between_images(ref, two, True)

  print('_' * 45)
  print("DISTANCE BETWEEN THE 2 PAIRS = {}".format(abs(pair1_dist - pair2_dist)))
  print('-' * 45)

# %%
show_dist_between_pairs(10, 12, 131)
# Out:
# ---------------------------------------------
# DISTANCE BETWEEN THESE 2 IMAGES = 0.181101918221
# .............................................
# DISTANCE BETWEEN THESE 2 IMAGES = 0.463276535273
# _____________________________________________
# DISTANCE BETWEEN THE 2 PAIRS = 0.282174617052
# ---------------------------------------------

# %%
show_dist_between_pairs(30, 31, 100)
# Out:
# ---------------------------------------------
# DISTANCE BETWEEN THESE 2 IMAGES = 0.258836209774
# .............................................
# DISTANCE BETWEEN THESE 2 IMAGES = 0.927035689354
# _____________________________________________
# DISTANCE BETWEEN THE 2 PAIRS = 0.66819947958
# ---------------------------------------------

# %%
show_dist_between_pairs(70, 72, 115)
# Out:
# ---------------------------------------------
# DISTANCE BETWEEN THESE 2 IMAGES = 0.270971387625
# .............................................
# DISTANCE BETWEEN THESE 2 IMAGES = 1.14188015461
# _____________________________________________
# DISTANCE BETWEEN THE 2 PAIRS = 0.870908737183
# ---------------------------------------------

# %% [markdown]
# #### Now lets build a simple fully connected neural network classifier to predict person in the given image.

# %% [markdown]
# If you observe distances between more pairs the difference is not constant between opposite pairs. So we train a fully connected neural network with very limited dataset to classiffy each embedding into the person. Lets prepare the data for training a fully connected neural network using keras

# %%
import keras

targets = np.array([int(m.name) for m in metadata])

num_classes = 11
# convert class vectors to one-hot encodings
y = keras.utils.to_categorical(targets, num_classes)


train_idx = np.arange(1, metadata.shape[0], 2) # Take all odd indices as training set
test_idx = np.arange(0, metadata.shape[0], 2) # Take all even indices as test set

## checking the shapes of metaadata and test and train sets
print("TOTAL # OF IMAGES      : {}".format(metadata.shape))
print("# OF TRAINING IMAGES   : {}".format(train_idx.shape))
print("# OF TEST IMAGES       : {}".format(test_idx.shape))
print("-" * 45)


# one half as train examples of 10 identities
X_train = np.array(embeddings)[train_idx]
X_test = np.array(embeddings)[test_idx]


y_train = y[train_idx]
y_test = y[test_idx]



print("TRAINING FEATURES SHAPE : {}".format(X_train.shape))
print("TRAINING LABELS SHAPE   : {}".format(y_train.shape))
print("-" * 45)
print("TEST FEATURES SHAPE : {}".format(X_test.shape))
print("TEST LABELS SHAPE   : {}".format(y_test.shape))
# Out:
# TOTAL # OF IMAGES      : (201,)
# # OF TRAINING IMAGES   : (100,)
# # OF TEST IMAGES       : (101,)
# ---------------------------------------------
# TRAINING FEATURES SHAPE : (100, 128)
# TRAINING LABELS SHAPE   : (100, 11)
# ---------------------------------------------
# TEST FEATURES SHAPE : (101, 128)
# TEST LABELS SHAPE   : (101, 11)

# %% [markdown]
# # 6. Build a 1 layered fully connected neural network using keras and report the accuracy - 20 marks
# Hint: Create only one layer with 11 neurons as we have 11 classes and mention the input_dim as 128 as the embeddings are of 128 length. Use a small batch size like 4 and use softmax as the activation function of the layer.
# You might have to train upto 80 epochs to get decent accuracy. You can use an Adam optimizer for the training part

# %%
vanilla_model = Sequential()
vanilla_model.add(Dense(11, 
                        input_shape=(128,),
                        activation='softmax'))

vanilla_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
early_stopping = callbacks.EarlyStopping(monitor='val_loss', min_delta=0,
                                         patience=10, verbose=1, mode='auto')

vanilla_model.fit(X_train, y_train, batch_size=4, epochs=400,
          validation_data=(X_test, y_test),
          callbacks=[early_stopping])

loss, acc = vanilla_model.evaluate(X_test, y_test, batch_size=4)

print('Test loss (LOWER is better)      : {}'.format(loss))
print('Test accuracy (HIGHER is better) : {}'.format(acc))
# Out:
# Train on 100 samples, validate on 101 samples
# Epoch 1/400
# 100/100 [==============================] - 1s 10ms/step - loss: 2.3994 - acc: 0.1200 - val_loss: 2.3860 - val_acc: 0.1287
# Epoch 2/400
# 100/100 [==============================] - 0s 685us/step - loss: 2.3437 - acc: 0.1800 - val_loss: 2.3442 - val_acc: 0.1584
# Epoch 3/400
# 100/100 [==============================] - 0s 666us/step - loss: 2.2974 - acc: 0.2500 - val_loss: 2.3039 - val_acc: 0.1881
# Epoch 4/400
# 100/100 [==============================] - 0s 674us/step - loss: 2.2556 - acc: 0.3400 - val_loss: 2.2665 - val_acc: 0.2970
# Epoch 5/400
# 100/100 [==============================] - 0s 660us/step - loss: 2.2153 - acc: 0.4600 - val_loss: 2.2341 - val_acc: 0.4158
# Epoch 6/400
# 100/100 [==============================] - 0s 683us/step - loss: 2.1785 - acc: 0.5700 - val_loss: 2.2026 - val_acc: 0.5149
# Epoch 7/400
# 100/100 [==============================] - 0s 681us/step - loss: 2.1433 - acc: 0.6100 - val_loss: 2.1711 - val_acc: 0.5743
# Epoch 8/400
# 100/100 [==============================] - 0s 689us/step - loss: 2.1091 - acc: 0.6300 - val_loss: 2.1429 - val_acc: 0.5941
# Epoch 9/400
# 100/100 [==============================] - 0s 673us/step - loss: 2.0772 - acc: 0.6700 - val_loss: 2.1149 - val_acc: 0.6436
# Epoch 10/400
# 100/100 [==============================] - 0s 684us/step - loss: 2.0466 - acc: 0.7100 - val_loss: 2.0893 - val_acc: 0.6535
# Epoch 11/400
# 100/100 [==============================] - 0s 685us/step - loss: 2.0155 - acc: 0.7600 - val_loss: 2.0626 - val_acc: 0.6931
# Epoch 12/400
# 100/100 [==============================] - 0s 675us/step - loss: 1.9866 - acc: 0.7800 - val_loss: 2.0388 - val_acc: 0.7030
# Epoch 13/400
# 100/100 [==============================] - 0s 702us/step - loss: 1.9578 - acc: 0.7900 - val_loss: 2.0143 - val_acc: 0.7129
# Epoch 14/400
# 100/100 [==============================] - 0s 659us/step - loss: 1.9311 - acc: 0.8100 - val_loss: 1.9907 - val_acc: 0.7129
# Epoch 15/400
# 100/100 [==============================] - 0s 661us/step - loss: 1.9042 - acc: 0.8100 - val_loss: 1.9676 - val_acc: 0.7030
400
# 100/100 [==============================] - 0s 683us/step - loss: 0.1445 - acc: 0.9900 - val_loss: 0.5564 - val_acc: 0.8614
# Epoch 389/400
# 100/100 [==============================] - 0s 683us/step - loss: 0.1438 - acc: 0.9900 - val_loss: 0.5558 - val_acc: 0.8614
# Epoch 390/400
# 100/100 [==============================] - 0s 714us/step - loss: 0.1429 - acc: 0.9900 - val_loss: 0.5556 - val_acc: 0.8614
# Epoch 391/400
# 100/100 [==============================] - 0s 702us/step - loss: 0.1422 - acc: 0.9900 - val_loss: 0.5555 - val_acc: 0.8614
# Epoch 392/400
# 100/100 [==============================] - 0s 697us/step - loss: 0.1418 - acc: 0.9900 - val_loss: 0.5552 - val_acc: 0.8614
# Epoch 393/400
# 100/100 [==============================] - 0s 712us/step - loss: 0.1411 - acc: 0.9900 - val_loss: 0.5556 - val_acc: 0.8614
# Epoch 394/400
# 100/100 [==============================] - 0s 785us/step - loss: 0.1406 - acc: 0.9900 - val_loss: 0.5541 - val_acc: 0.8614
# Epoch 395/400
# 100/100 [==============================] - 0s 717us/step - loss: 0.1399 - acc: 0.9900 - val_loss: 0.5545 - val_acc: 0.8614
# Epoch 396/400
# 100/100 [==============================] - 0s 690us/step - loss: 0.1392 - acc: 0.9900 - val_loss: 0.5542 - val_acc: 0.8614
# Epoch 397/400
# 100/100 [==============================] - 0s 712us/step - loss: 0.1388 - acc: 0.9900 - val_loss: 0.5535 - val_acc: 0.8614
# Epoch 398/400
# 100/100 [==============================] - 0s 688us/step - loss: 0.1379 - acc: 0.9900 - val_loss: 0.5529 - val_acc: 0.8614
# Epoch 399/400
# 100/100 [==============================] - 0s 705us/step - loss: 0.1373 - acc: 0.9900 - val_loss: 0.5532 - val_acc: 0.8614
# Epoch 400/400
# 100/100 [==============================] - 0s 707us/step - loss: 0.1367 - acc: 0.9900 - val_loss: 0.5527 - val_acc: 0.8614
# 101/101 [==============================] - 0s 341us/step
# Test loss (LOWER is better)      : 0.55267886065
# Test accuracy (HIGHER is better) : 0.861386138614

# %% [markdown]
# # 7.  Test the classifier  - 10 marks
#
# Take 35th image from test set and plot the image, report to which person(folder name in dataset) the image belongs to.

# %%
i_test = 35
i_orig = test_idx[i_test]
    
print("PREDICTED SOFTMAX OUTPUT PER NEURON :")
print(vanilla_model.predict(np.reshape(X_test[i_test], (1, 128))))

print('_' * 45)
print("PREDICTED PERSON (ID/FOLDER NAME) : {}".format(np.argmax(vanilla_model.predict(np.reshape(X_test[i_test], (1, 128))))))
print("ACTUAL PERSON (ID/FOLDER NAME)    : {}".format(metadata[i_orig].name))

print('_' * 45)
plt.imshow(load_image(metadata[i_orig].image_path())[...,::-1])
plt.show()
# Out:
# PREDICTED SOFTMAX OUTPUT PER NEURON :
# [[1.0727377e-02 4.4563366e-03 1.3139432e-03 4.3242332e-04 3.2006745e-05
#   5.9476134e-04 4.3978565e-03 9.7484314e-01 2.6674679e-05 2.7795174e-04
#   2.8975036e-03]]
# _____________________________________________
# PREDICTED PERSON (ID/FOLDER NAME) : 7
# ACTUAL PERSON (ID/FOLDER NAME)    : 7
# _____________________________________________

# %%
i_test = 45
i_orig = test_idx[i_test]
    
print("PREDICTED SOFTMAX OUTPUT PER NEURON :")
print(vanilla_model.predict(np.reshape(X_test[i_test], (1, 128))))

print('_' * 45)
print("PREDICTED PERSON (ID/FOLDER NAME) : {}".format(np.argmax(vanilla_model.predict(np.reshape(X_test[i_test], (1, 128))))))
print("ACTUAL PERSON (ID/FOLDER NAME)    : {}".format(metadata[i_orig].name))

print('_' * 45)
plt.imshow(load_image(metadata[i_orig].image_path())[...,::-1])
plt.show()
# Out:
# PREDICTED SOFTMAX OUTPUT PER NEURON :
# [[7.9355920e-03 1.2643261e-01 6.6538916e-05 1.0876713e-03 3.9471403e-02
#   1.5268082e-04 6.6373600e-03 1.2318867e-03 3.4181112e-01 9.7596738e-04
#   4.7419718e-01]]
# _____________________________________________
# PREDICTED PERSON (ID/FOLDER NAME) : 10
# ACTUAL PERSON (ID/FOLDER NAME)    : 10
# _____________________________________________

# %% [markdown]
# ## Optional Exercise - For people who are familiar with SVMs, you can use an SVM classifier(If you already know how to use the scikit-learn package for it) to do this last part being done by the fully connected neural network.

# %%
from sklearn.metrics import f1_score, accuracy_score
from sklearn.preprocessing import LabelEncoder
from sklearn.svm import LinearSVC

targets = np.array([int(m.name) for m in metadata])

encoder = LabelEncoder()
encoder.fit(targets)

# Numerical encoding of identities
y = encoder.transform(targets)

train_idx = np.arange(1, metadata.shape[0], 2) # Take all odd indices as training set
test_idx = np.arange(0, metadata.shape[0], 2) # Take all even indices as test set

## checking the shapes of metaadata and test and train sets
print("TOTAL # OF IMAGES      : {}".format(metadata.shape))
print("# OF TRAINING IMAGES   : {}".format(train_idx.shape))
print("# OF TEST IMAGES       : {}".format(test_idx.shape))
print("-" * 45)


# one half as train examples of 10 identities
X_train = np.array(embeddings)[train_idx]
X_test = np.array(embeddings)[test_idx]


y_train = y[train_idx]
y_test = y[test_idx]



print("TRAINING FEATURES SHAPE : {}".format(X_train.shape))
print("TRAINING LABELS SHAPE   : {}".format(y_train.shape))
print("-" * 45)
print("TEST FEATURES SHAPE : {}".format(X_test.shape))
print("TEST LABELS SHAPE   : {}".format(y_test.shape))
# Out:
# TOTAL # OF IMAGES      : (201,)
# # OF TRAINING IMAGES   : (100,)
# # OF TEST IMAGES       : (101,)
# ---------------------------------------------
# TRAINING FEATURES SHAPE : (100, 128)
# TRAINING LABELS SHAPE   : (100,)
# ---------------------------------------------
# TEST FEATURES SHAPE : (101, 128)
# TEST LABELS SHAPE   : (101,)

# %%
svc = LinearSVC()
svc.fit(X_train, y_train)
acc_svc = accuracy_score(y_test, svc.predict(X_test))

print('SVM accuracy = {}'.format(acc_svc))
print('_' * 45)


i_test = 35
i_orig = test_idx[i_test]
    
print("PREDICTED PERSON (ID/FOLDER NAME) : {}".format(svc.predict(np.reshape(X_test[i_test], (1, 128)))))
print("ACTUAL PERSON (ID/FOLDER NAME)    : {}".format(metadata[i_orig].name))

print('_' * 45)
plt.imshow(load_image(metadata[i_orig].image_path())[...,::-1])
plt.show()
# Out:
# SVM accuracy = 0.861386138614
# _____________________________________________
# PREDICTED PERSON (ID/FOLDER NAME) : [7]
# ACTUAL PERSON (ID/FOLDER NAME)    : 7
# _____________________________________________

# %%
i_test = 45
i_orig = test_idx[i_test]
    
print("PREDICTED PERSON (ID/FOLDER NAME) : {}".format(svc.predict(np.reshape(X_test[i_test], (1, 128)))))
print("ACTUAL PERSON (ID/FOLDER NAME)    : {}".format(metadata[i_orig].name))

print('_' * 45)
plt.imshow(load_image(metadata[i_orig].image_path())[...,::-1])
plt.show()
# Out:
# PREDICTED PERSON (ID/FOLDER NAME) : [10]
# ACTUAL PERSON (ID/FOLDER NAME)    : 10
# _____________________________________________
